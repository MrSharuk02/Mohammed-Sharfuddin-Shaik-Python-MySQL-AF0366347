# %% [markdown]
# <h1 style = 'color : tomato'> <u>Project Title: Hotel Management System</u></h1>

# %% [markdown]
# <h1 style = 'color : skyblue'>Purpose:</h1>

# %% [markdown]
# <i>The purpose of the project is to leverage data analysis techniques to extract actionable insights from a hotel management system. By analyzing customer demographics, booking trends, payment behavior, service availability, and staff distribution, the project aims to inform strategic decisions in marketing, pricing, operations, and staffing. The conclusion justifies these efforts by highlighting the potential for tailored strategies to enhance customer satisfaction, optimize operations, and increase profitability. Through data-driven decision-making, the hotel can better meet guest needs, improve efficiency, and drive business success in the competitive hospitality landscape.</i>

# %% [markdown]
# <h2>Step 1. Downloading necessary packages </h2>

# %%
pip install mysql-connector-python

# %% [markdown]
# <h2>Step 2. Importing necessary packages </h2>

# %%
# Python library for connecting to MySQL database using mysql-connector-python
import mysql.connector 
import numpy as np  # numpy library for numerical calculations
import matplotlib.pyplot as plt  #  Matplotlib for data Visualization
import pandas as pd  #  Pandas for Data manipulation 
import seaborn as sns   #  Seaborn for additional data Visualization

# %% [markdown]
# <h2>Step 3. Establishing Connection (Database connectivity from python to mysql database) </h2>

# %%
connection = mysql.connector.connect(
user='root',
password='Sharfoddin@28',
host='localhost',
database='hotelmanagementsystem'
)

# Create a cursor object to execute SQL queries
cursor = connection.cursor()
# Query data from the 'Customers' table
cursor.execute('SELECT * FROM customers')

#After fetching data from the database we are storing it into Pandas DataFrame
customers_df = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in
cursor.description])

# Query data from the 'Rooms' table
cursor.execute('SELECT * FROM rooms')
rooms_df = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in
cursor.description])

# Query data from the 'bookings' table
cursor.execute('SELECT * FROM bookings')
bookings_df = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in
cursor.description])

# Query data from the 'payments' table
cursor.execute('SELECT * FROM payments')
payments_df = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in
cursor.description])

# Query data from the 'staff' table
cursor.execute('SELECT * FROM staff')
staff_df = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in
cursor.description])

# Query data from the 'services' table
cursor.execute('SELECT * FROM services')
services_df = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in
cursor.description])

# Query data from the 'booking_services' table
cursor.execute('SELECT * FROM booking_services')
booking_services_df = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in
cursor.description])

# %% [markdown]
# <h2>Step 4. Data View </h2>

# %%
# Print all head in each DataFrame
dataframes = {
    'Customers': customers_df,
    'Rooms': rooms_df,
    'Bookings': bookings_df,
    'Payments': payments_df,
    'Staff': staff_df,
    'Services': services_df,
    'booking_services': booking_services_df
}

for table, df in dataframes.items():
    print("***********************")  # Add a blank line for separation
    print(f"5 Head rows in {table}:")
    print(df.head())
# Out:
# ***********************
# 5 Head rows in Customers:
#    customer_id first_name  last_name  age  gender  \
# 0            1      Karen      Kelly   71  Female
# 1            2    Michele  Daugherty   56    Male
# 2            3       Mark      Patel   42  Female
# 3            4    Theresa       Hill   28    Male
# 4            5        Amy       York   26  Female
#
#                           email            phone  \
# 0     shawcatherine@example.org  +1-923-780-9580
# 1            hkline@example.org    (657)253-4886
# 2           laura22@example.net     295-994-9623
# 3   samanthajohnson@example.org  (469)200-4244x2
# 4  hernandezkristin@example.org     375-397-7694
#
#                                              address
# 0         7616 Moreno Branch, South Bianca, AK 89400
# 1                   Unit 4843 Box 4535, DPO AA 60764
# 2            5149 Macias Trace, Port Nancy, PW 21731
# 3           215 Darren Landing, Riveraview, MS 50568
# ...

# %%
# Print all null in each DataFrame
dataframes = {
    'Customers': customers_df,
    'Rooms': rooms_df,
    'Bookings': bookings_df,
    'Payments': payments_df,
    'Staff': staff_df,
    'Services': services_df,
    'booking_services': booking_services_df
}

for table, df in dataframes.items():
    print("***********************")  # Add a blank line for separation
    print(f"Null elements in {table}:")
    print(df.isnull().sum())
# Out:
# ***********************
# Null elements in Customers:
# customer_id    0
# first_name     0
# last_name      0
# age            0
# gender         0
# email          0
# phone          0
# address        0
# dtype: int64
# ***********************
# Null elements in Rooms:
# room_id            0
# room_number        0
# room_type          0
# capacity           0
# price_per_night    0
# status             0
# dtype: int64
# ***********************
# Null elements in Bookings:
# booking_id        0
# customer_id       0
# room_id           0
# staff_id          0
# check_in_date     0
# check_out_date    0
# total_amount      0
# booking_status    0
# dtype: int64
# ***********************
# Null elements in Payments:
# payment_id        0
# booking_id        0
# payment_date      0
# amount            0
# payment_method    0
# payment_status    0
# dtype: int64
# ***********************
# Null elements in Staff:
# staff_id      0
# first_name    0
# last_name     0
# age           0
# ...

# %%
# Print all duplicates in each DataFrame
dataframes = {
    'Customers': customers_df,
    'Rooms': rooms_df,
    'Bookings': bookings_df,
    'Payments': payments_df,
    'Staff': staff_df,
    'Services': services_df,
    'booking_services': booking_services_df
}

for table, df in dataframes.items():
    print("***********************")  # Add a blank line for separation
    print(f"Duplicates in {table}:")
    print(df.duplicated().sum())
# Out:
# ***********************
# Duplicates in Customers:
# 0
# ***********************
# Duplicates in Rooms:
# 0
# ***********************
# Duplicates in Bookings:
# 0
# ***********************
# Duplicates in Payments:
# 0
# ***********************
# Duplicates in Staff:
# 0
# ***********************
# Duplicates in Services:
# 0
# ***********************
# Duplicates in booking_services:
# 0

# %%
# Print all unique in each DataFrame
dataframes = {
    'Customers': customers_df,
    'Rooms': rooms_df,
    'Bookings': bookings_df,
    'Payments': payments_df,
    'Staff': staff_df,
    'Services': services_df,
    'booking_services': booking_services_df
}

for table, df in dataframes.items():
    print("***********************")  # Add a blank line for separation
    print(f"Unique in {table}:")
    print(df.nunique())
# Out:
# ***********************
# Unique in Customers:
# customer_id    500
# first_name     236
# last_name      326
# age             58
# gender           2
# email          500
# phone          500
# address        500
# dtype: int64
# ***********************
# Unique in Rooms:
# room_id            500
# room_number        500
# room_type            4
# capacity             4
# price_per_night    499
# status               3
# dtype: int64
# ***********************
# Unique in Bookings:
# booking_id        500
# customer_id       313
# room_id           322
# staff_id          300
# check_in_date     274
# check_out_date    226
# total_amount      498
# booking_status      3
# dtype: int64
# ***********************
# Unique in Payments:
# payment_id        500
# booking_id        322
# payment_date      272
# amount            500
# payment_method      4
# payment_status      3
# dtype: int64
# ***********************
# Unique in Staff:
# staff_id      500
# first_name    240
# ...

# %%
# Print all statistics in each DataFrame
dataframes = {
    'Customers': customers_df,
    'Rooms': rooms_df,
    'Bookings': bookings_df,
    'Payments': payments_df,
    'Staff': staff_df,
    'Services': services_df,
    'booking_services': booking_services_df
}

for table, df in dataframes.items():
    print("***********************")  # Add a blank line for separation
    print(f"Satistics in {table}:")
    print(df.describe())
# Out:
# ***********************
# Satistics in Customers:
#        customer_id         age
# count   500.000000  500.000000
# mean    250.500000   45.354000
# std     144.481833   17.496197
# min       1.000000   18.000000
# 25%     125.750000   29.000000
# 50%     250.500000   46.000000
# 75%     375.250000   61.000000
# max     500.000000   75.000000
# ***********************
# Satistics in Rooms:
#           room_id    capacity
# count  500.000000  500.000000
# mean   250.500000    2.562000
# std    144.481833    1.144016
# min      1.000000    1.000000
# 25%    125.750000    2.000000
# 50%    250.500000    3.000000
# 75%    375.250000    4.000000
# max    500.000000    4.000000
# ***********************
# Satistics in Bookings:
#        booking_id  customer_id     room_id  staff_id
# count  500.000000   500.000000  500.000000  500.0000
# mean   250.500000   254.406000  254.432000  262.4580
# std    144.481833   141.173557  141.772693  145.6565
# ...

# %%
# Print all columns in each DataFrame
dataframes = {
    'Customers': customers_df,
    'Rooms': rooms_df,
    'Bookings': bookings_df,
    'Payments': payments_df,
    'Staff': staff_df,
    'Services': services_df,
    'booking_services': booking_services_df
}

for table, df in dataframes.items():
    print("***********************")  # Add a blank line for separation
    print(f"Head 5 rows in {table}:")
    print(df.info())
# Out:
# ***********************
# Head 5 rows in Customers:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  500 non-null    int64
#  1   first_name   500 non-null    object
#  2   last_name    500 non-null    object
#  3   age          500 non-null    int64
#  4   gender       500 non-null    object
#  5   email        500 non-null    object
#  6   phone        500 non-null    object
#  7   address      500 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB
# None
# ***********************
# Head 5 rows in Rooms:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   room_id          500 non-null    int64
#  1   room_number      500 non-null    object
# ...

# %% [markdown]
# # Display the number of rows and columns in each DataFrame 👇

# %%
# Display the number of rows and columns in each DataFrame
for table, df in dataframes.items():
    print("***********************")  # Add a blank line for separation
    print(f"Table: {table}")
    num_rows, num_cols = df.shape
    print(f"Number of Columns: {num_cols}")
    print(f"Number of Rows: {num_rows}")
# Out:
# ***********************
# Table: Customers
# Number of Columns: 8
# Number of Rows: 500
# ***********************
# Table: Rooms
# Number of Columns: 6
# Number of Rows: 500
# ***********************
# Table: Bookings
# Number of Columns: 8
# Number of Rows: 500
# ***********************
# Table: Payments
# Number of Columns: 6
# Number of Rows: 500
# ***********************
# Table: Staff
# Number of Columns: 8
# Number of Rows: 500
# ***********************
# Table: Services
# Number of Columns: 5
# Number of Rows: 500
# ***********************
# Table: booking_services
# Number of Columns: 5
# Number of Rows: 500

# %% [markdown]
# # Print all columns in each DataFrame 👇

# %%
# Print all columns in each DataFrame
dataframes = {
    'Customers': customers_df,
    'Rooms': rooms_df,
    'Bookings': bookings_df,
    'Payments': payments_df,
    'Staff': staff_df,
    'Services': services_df,
    'booking_services': booking_services_df
}

for table, df in dataframes.items():
    print("***********************")  # Add a blank line for separation
    print(f"Head 5 rows in {table}:")
    print(df.columns)
# Out:
# ***********************
# Head 5 rows in Customers:
# Index(['customer_id', 'first_name', 'last_name', 'age', 'gender', 'email',
#        'phone', 'address'],
#       dtype='object')
# ***********************
# Head 5 rows in Rooms:
# Index(['room_id', 'room_number', 'room_type', 'capacity', 'price_per_night',
#        'status'],
#       dtype='object')
# ***********************
# Head 5 rows in Bookings:
# Index(['booking_id', 'customer_id', 'room_id', 'staff_id', 'check_in_date',
#        'check_out_date', 'total_amount', 'booking_status'],
#       dtype='object')
# ***********************
# Head 5 rows in Payments:
# Index(['payment_id', 'booking_id', 'payment_date', 'amount', 'payment_method',
#        'payment_status'],
#       dtype='object')
# ***********************
# Head 5 rows in Staff:
# Index(['staff_id', 'first_name', 'last_name', 'age', 'gender', 'position',
#        'hire_date', 'salary'],
#       dtype='object')
# ***********************
# Head 5 rows in Services:
# ...

# %% [markdown]
# <h1 style = 'color:tomato'> <u>Visualizing the data</u> </h1>

# %% [markdown]
# # Percentage of Gender Distribution 👇

# %%
# Gender Distribution
customers_df['gender'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Gender Distribution of Customers')
plt.show()

# %% [markdown]
# - <h4 style= 'color: lightgreen'>The provided pie chart illustrates the gender distribution among customers. It indicates that approximately 49.0% of the customers are male, while around 51.0% are female.</h4>

# %% [markdown]
# # Distribution of Customers by Age 👇

# %%
# 1. Distribution of Customers by Age
plt.figure(figsize=(10, 6))
plt.hist(customers_df['age'], bins=20, edgecolor='k', alpha=0.7)
plt.title('Distribution of Customers by Age')
plt.xlabel('Age')
plt.ylabel('Number of Customers')
plt.grid(True)
plt.show()

# %% [markdown]
# # Visualizing the distribution of room types using a count plot 👇

# %%
# Visualize the distribution of room types using a count plot
plt.figure(figsize=(8, 6))  # Set the figure size
ax = sns.countplot(x='room_type', data=rooms_df, palette='Set2', hue='room_type', legend=False)  # Create a count plot
plt.title('Room Type Distribution')  # Set the title of the plot
plt.xlabel('Room Type')  # Label the x-axis
plt.ylabel('Count')  # Label the y-axis
plt.xticks(rotation=0)  # Rotate the x-axis labels if needed

# Display the count values on top of each bar
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()  # Display the plot

# %% [markdown]
# - <h4 style= 'color: lightblue'>The Room Type Distribution graph illustrates the distribution of different types of rooms available in the hotel. In this graph Deluxe room has highest priority <br> <br>
# <b>Room Types:</b> The x-axis represents the different types of rooms available, such as Single, Double, Suite, or Deluxe.<br><br>
#     <b>Count:</b> The y-axis indicates the count or frequency of each room type, representing how many rooms of each type are available or booked.</h4>

# %% [markdown]
# # Room Capacity 👇

# %%
# Room Capacity
sns.histplot(rooms_df['capacity'], bins=10, kde=True)
plt.title('Room Capacity Distribution')
plt.xlabel('Capacity')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - <h4 style= 'color: pink'>The Room Capacity Distribution graph presents the distribution of room capacities available in the hotel. <br><br>
# <b>Capacity: </b>The x-axis represents the capacity of the rooms, indicating the number of occupants each room can accommodate.<br><br>
#    <b> Frequency:</b> The y-axis shows the frequency or count of rooms with a particular capacity, providing an overview of the distribution of room sizes available.
# </h4>

# %% [markdown]
# # Visualizing the distribution of booking statuses using a bar plot 👇

# %%
# Visualize the distribution of booking statuses using a bar plot with values displayed on top of each bar
plt.figure(figsize=(10, 6))  # Set the figure size
status_counts = bookings_df['booking_status'].value_counts()  # Get the count of each booking status
status_counts.plot(kind='bar', color='gold')  # Create a bar plot
plt.title('Booking Status Distribution')  # Set the title of the plot
plt.xlabel('Booking Status')  # Set the label for the x-axis
plt.ylabel('Count')  # Set the label for the y-axis
plt.xticks(rotation=0)  # Rotate x-axis labels if needed

# Display the count values on top of each bar
for i, count in enumerate(status_counts):
    plt.text(i, count + 15, str(count), ha='center', va='top')

plt.show()  # Display the plot

# %% [markdown]
# - <h4 style = 'color: lightgray'>The Booking Status Distribution graph visualizes the distribution of booking statuses within the hotel management system. <br> <br>
# <b>Booking Status:</b> The x-axis displays different booking statuses, including "Confirmed," "Cancelled," and "Completed." <br> <br>
# <b>Count:</b> The y-axis represents the count or frequency of bookings corresponding to each status category. <br></h4>

# %% [markdown]
# # Visualizing the distribution of payment amounts using a histogram 👇

# %%
# Visualize the distribution of payment amounts using a histogram
sns.histplot(payments_df['amount'], bins=10, kde=True)  # Create a histogram
plt.title('Payment Amount Distribution')  # Set the title of the plot
plt.xlabel('Amount')  # Set the label for the x-axis
plt.ylabel('Frequency')  # Set the label for the y-axis
plt.show()  # Display the plot

# %% [markdown]
# - <h4 style = 'color:skyblue'>The Payment Amount Distribution graph illustrates the distribution of payment amounts made within the hotel management system. <br> <br>
# <b>Payment Amount:</b> The x-axis represents different payment amounts, which are grouped into bins for visualization. <br> <br>
# <b>Frequency:</b> The y-axis indicates the frequency of payments falling within each amount range. <br></h4>

# %% [markdown]
# # Visualize the distribution of payment methods using a pie chart 👇

# %%
# Visualize the distribution of payment methods using a pie chart
payments_df['payment_method'].value_counts().plot(kind='pie', autopct='%1.1f%%')  # Create a pie chart
plt.title('Payment Method Distribution')  # Set the title of the plot
plt.show()  # Display the plot

# %% [markdown]
# - <h4 >The Payment Method Distribution graph depicts the distribution of payment methods utilized within the hotel management system. <br> <br>
# <b>Payment Methods:</b> The pie chart segments represent different payment methods used by customers, such as Credit Card, Debit Card, Cash, or Online payment. <br> <br>
# <b>Percentage Breakdown:</b> Each segment of the pie chart displays the proportion of payments made through a specific payment method, indicated as a percentage of the total. <br></h4>

# %% [markdown]
# # Visualizing the distribution of staff positions using a bar plot 👇

# %%
# Visualize the distribution of staff positions using a bar plot
plt.figure(figsize=(10, 6))  # Set the figure size
ax = sns.countplot(x='position', data=staff_df, color='lightgreen')  # Create a bar plot
plt.title('Staff Position Distribution')  # Set the title of the plot
plt.xlabel('Position')  # Label the x-axis
plt.ylabel('Count')  # Label the y-axis
plt.xticks(rotation=0)  # Rotate the x-axis labels if needed

# Display the count values on top of each bar
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()  # Display the plot

# %% [markdown]
# - <h4 style = 'color:Violet'>The Staff Position Distribution graph illustrates the distribution of different positions held by staff members within the hotel management system. <br> <br>
# <b>Staff Positions:</b> The bar chart displays various positions occupied by staff members, such as Manager, Receptionist, Housekeeping, or Chef. <br> <br>
# <b>Count: </b>The height of each bar represents the number of staff members holding a particular position. <br></h4>

# %% [markdown]
# # Visualizing the distribution of service types using a bar plot 👇

# %%
# Visualize the distribution of service types using a count plot
ax = sns.countplot(x='service_name', data=services_df,color='skyblue')
plt.title('Service Type Distribution')
plt.xlabel('Service Type')
plt.ylabel('Count')
plt.xticks(rotation=30)

# Add count values on top of each bar
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %% [markdown]
# - <h4>This bar plot visualizes the distribution of service types offered by the hotel management system. Each bar represents a service type, and the height of the bar indicates the count of occurrences of that service type in the dataset.</h4>

# %% [markdown]
# # Visualizing the distribution of service availability using a bar plot 👇

# %%
# Visualize the distribution of service availability using a count plot
plt.figure(figsize=(8, 6))  # Set the figure size
ax = sns.countplot(x='service_status', data=services_df)  # Create a count plot
plt.title('Service Availability')  # Set the title of the plot
plt.xlabel('Service Status')  # Label the x-axis
plt.ylabel('Count')  # Label the y-axis

# Display the count values on top of each bar
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()  # Display the plot

# %% [markdown]
# - <h4 style = 'color:gray'>The Service Availability graph depicts the availability status of different services offered by the hotel management system. <br> <br>
# <b>Service Status: </b> The bar chart categorizes services based on their availability status, which can be either "Available" or "Unavailable."<br> <br>
# <b>Count: </b>Each bar represents the number of services falling under a particular availability status category. <br></h4>

# %% [markdown]
# # Visualizing the distribution of service prices using a histogram 👇

# %%
# Visualize the distribution of service prices using a histogram
sns.histplot(services_df['price'], bins=10, kde=True)  # Create a histogram with kernel density estimation
plt.title('Service Price Distribution')  # Set the title of the plot
plt.xlabel('Price')  # Label the x-axis
plt.ylabel('Frequency')  # Label the y-axis
plt.show()  # Display the plot

# %% [markdown]
# - <h4>The Service Price Distribution graph illustrates the distribution of prices for various services offered by the hotel management system. <br> <br>
# <b>Price Distribution: </b> The histogram displays the frequency distribution of service prices, providing insights into the pricing structure of different services. <br> <br>
# <b>Bins: </b>The data is divided into bins or intervals along the x-axis, representing different price ranges.<br><br>
#    <b> Frequency: </b> Each bar represents the number of services falling within a specific price range.
#     <br><br> <b> KDE (Kernel Density Estimation):</b> The overlaid KDE curve provides a smooth estimate of the probability density function of service prices, offering additional insights into the underlying distribution pattern.
#     <br></h4>

# %% [markdown]
# # Room Status Distribution 👇

# %%
# Room Status Distribution
room_status_counts = rooms_df['status'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(room_status_counts, labels=room_status_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Room Status Distribution')
plt.show()

# %% [markdown]
# # Resample the data to get monthly revenue 👇

# %%
# Resample the data to get monthly revenue
monthly_revenue = payments_df.resample('ME')['amount'].sum()

# Check the resampled data
print(monthly_revenue)

# Plot the monthly revenue trend
plt.figure(figsize=(12, 6))
plt.plot(monthly_revenue.index, monthly_revenue, marker='o', linestyle='-', color='green')
plt.title('Monthly Revenue Trend')
plt.xlabel('Date')
plt.ylabel('Total Revenue')
plt.grid(True)
plt.show()
# Out:
# payment_date
# 2023-06-30     50163.83
# 2023-07-31    130811.05
# 2023-08-31     98675.53
# 2023-09-30    131472.56
# 2023-10-31    105477.97
# 2023-11-30    115057.42
# 2023-12-31     98417.43
# 2024-01-31    108541.19
# 2024-02-29     95770.14
# 2024-03-31    128795.34
# 2024-04-30    116170.26
# 2024-05-31    105563.22
# 2024-06-30     23012.09
# Freq: ME, Name: amount, dtype: object

# %% [markdown]
# # Conclusion:

# %% [markdown]
# - <b>Gender Distribution: </b> The gender distribution of customers reveals that approximately 49.0% are male and 51.0% are female. This information can be used to target marketing campaigns towards specific gender demographics.
# - <b>Room Type Distribution: </b> The distribution of room types shows the proportion of different room types available in the hotel. This insight can guide pricing strategies and room allocation based on demand for each type.
# - <b>Room Capacity:  </b> Understanding the distribution of room capacities helps in optimizing room occupancy and pricing strategies. It provides insights into the most preferred room sizes among customers.
# - <b>Booking Status Distribution: </b> The distribution of booking statuses indicates the current status of bookings, including confirmed, cancelled, and completed. This information is crucial for managing reservations and optimizing booking processes.
# - <b> Payment Distribution:</b> Analyzing the distribution of payment amounts provides insights into the typical spending behavior of customers. It helps in evaluating pricing strategies and identifying opportunities for revenue optimization.
# - <b>Payment Method Distribution: </b>Understanding the preferred payment methods of customers helps in optimizing payment processing systems and providing convenient payment options.
# - <b> Staff Position Distribution: </b>The distribution of staff positions gives an overview of the workforce composition within the hotel. It helps in workforce management and identifying areas where additional staffing may be required.
# - <b>Service Availability: </b>Analyzing the availability of services helps in ensuring that essential services are adequately provided to customers. It also guides decisions regarding service expansion or modification based on demand.
# - <b> Service Price Distribution:</b> Understanding the distribution of service prices helps in pricing service offerings competitively and optimizing revenue generation from service sales. <br><br>
#   In conclusion, the analysis of hotel management system data provides valuable insights into customer demographics, booking patterns, payment behavior, staff composition, and service offerings. These insights can be leveraged to make informed business decisions, enhance customer satisfaction, and improve overall operational efficiency in the hotel industry.
