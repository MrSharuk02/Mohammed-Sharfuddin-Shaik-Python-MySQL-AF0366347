# %% [markdown]
# # 1. Libraries import
# #### Purpose: The aim of healthcare data analysis project is to
#
# - Enhance patient care and outcomes through personalized treatments and disease prevention strategies.
# - Optimize healthcare resources and operations to improve efficiency and reduce costs.
# - Monitor population health trends, detect disease outbreaks, and respond effectively to public health threats.
# - Improve healthcare quality and safety by identifying areas for improvement and implementing evidence-based practices.
# - Drive evidence-based decision-making, mitigate healthcare fraud, and promote health equity and access for all populations.

# %%
# Libraries Numerical operations and Data Manipulations
import numpy as np
import pandas as pd
# Visualization Libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2. Data Cleaning

# %% [markdown]
# ### 2.1 Reading data from CSV file

# %%
d_f = 'healthcare_dataset.csv'
data = pd.read_csv(d_f)
print(data)
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %% [markdown]
# #### The dataset includes the following columns for Healthcare Sales Analysis
# - Name : The name of the patient.
# - Age : The age of the patient.
# - Gender : The gender of the patient.
# - Blood Type : The blood type of the patient.
# - Medical Condition : The medical condition or diagnosis of the patient.
# - Date of Admission : The date when the patient was admitted to the hospital.
# - Doctor : The attending doctor responsible for the patient's care.
# - Hospital : The name or identifier of the hospital where the patient was admitted.
# - Insurance Provider : The insurance provider covering the patient's medical expenses.
# - Billing Amount : The total billing amount for the patient's treatment and services.
# - Room Number : The room number where the patient was accommodated during their stay.
# - Admission Type : The type of admission, such as emergency, elective, or urgent.
# - Discharge Date: The date when the patient was discharged from the hospital.
# - Medication : The medications prescribed to the patient during their hospitalization.
# - Test Results : The results of diagnostic tests conducted on the patient.

# %% [markdown]
#  ## 👇 displayed top 10 rows values

# %%
data.head(10) # display top 10 rows values
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0      Tiffany Ramirez   81  Female         O-          Diabetes
# 1          Ruben Burns   35    Male         O+            Asthma
# 2            Chad Byrd   61    Male         B-           Obesity
# 3    Antonio Frederick   49    Male         B-            Asthma
# 4  Mrs. Brandy Flowers   51    Male         O-         Arthritis
# 5       Patrick Parker   41    Male        AB+         Arthritis
# 6       Charles Horton   82    Male        AB+      Hypertension
# 7         Patty Norman   55  Female         O-         Arthritis
# 8           Ryan Hayes   33    Male         A+          Diabetes
# 9         Sharon Perez   39  Female         O-            Asthma
#
#   Date of Admission           Doctor                   Hospital  \
# 0        2022-11-17   Patrick Parker           Wallace-Hamilton
# 1        2023-06-01    Diane Jackson  Burke, Griffin and Cooper
# ...

# %% [markdown]
# ## 👇 display bottom 10 rows values

# %%
data.tail(10) # display bottom 10 rows values
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 9990         Tracy Johnson   35    Male         A+         Arthritis
# 9991           John Holder   56  Female         A+            Asthma
# 9992     Gabriel Rodriguez   37    Male         O+      Hypertension
# 9993         Michael Munoz   39    Male         O-      Hypertension
# 9994          Jorge Obrien   69    Male         A+          Diabetes
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                      Hospital  \
# 9990        2020-10-30          Paul Bell  Freeman, Nguyen and Ferguson
# ...

# %% [markdown]
# ## 👇 display all columns

# %%
data.columns  # display all columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %% [markdown]
# - Display all column in the dataset

# %% [markdown]
# ## 👇 accessing the index of a DataFrame

# %%
data.index  # accessing the index of a DataFrame
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %% [markdown]
# - RangeIndex starting from 0, ending at 9999, with a step count 1.

# %% [markdown]
# ## 👇 The summary of the DataFrame

# %%
data.info() # info() provides a summary of the DataFrame's metadata.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10000 non-null  object
#  1   Age                 10000 non-null  int64
#  2   Gender              10000 non-null  object
#  3   Blood Type          10000 non-null  object
#  4   Medical Condition   10000 non-null  object
#  5   Date of Admission   10000 non-null  object
#  6   Doctor              10000 non-null  object
#  7   Hospital            10000 non-null  object
#  8   Insurance Provider  10000 non-null  object
#  9   Billing Amount      10000 non-null  float64
#  10  Room Number         10000 non-null  int64
#  11  Admission Type      10000 non-null  object
#  12  Discharge Date      10000 non-null  object
#  13  Medication          10000 non-null  object
#  14  Test Results        10000 non-null  object
# ...

# %% [markdown]
# ## 👇 the count of unique elements in each column of the DataFrame

# %%
data.nunique()     # returns the count of unique elements in each column of the DataFrame
# Out:
# Name                   9378
# Age                      68
# Gender                    2
# Blood Type                8
# Medical Condition         6
# Date of Admission      1815
# Doctor                 9416
# Hospital               8639
# Insurance Provider        5
# Billing Amount        10000
# Room Number             400
# Admission Type            3
# Discharge Date         1834
# Medication                5
# Test Results              3
# dtype: int64

# %% [markdown]
# ## 👇 the dimensions of the DataFrame

# %%
data.shape   # returns a tuple representing the dimensions of the DataFrame
# Out:
# (10000, 15)

# %% [markdown]
# - Here Dataset consists of 1000 rows and 15 columns.

# %% [markdown]
# ## 👇 description of statistical information

# %%
data.describe()  # describe statistical information
# Out:
#                 Age  Billing Amount   Room Number
# count  10000.000000    10000.000000  10000.000000
# mean      51.452200    25516.806778    300.082000
# std       19.588974    14067.292709    115.806027
# min       18.000000     1000.180837    101.000000
# 25%       35.000000    13506.523967    199.000000
# 50%       52.000000    25258.112566    299.000000
# 75%       68.000000    37733.913727    400.000000
# max       85.000000    49995.902283    500.000000

# %% [markdown]
# - From above data we are getting statistical information like count,mean, standard deviation, minimum,25%(Represents the first quartile),50%(Represents the median or second quartile),75%(Represents the third quartile),Maximum Values.

# %% [markdown]
# ## 👇 Displays na or null values.

# %%
data.isnull().sum()  # Display na or null values.
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %% [markdown]
# ## 👇 calculates the number of duplicate rows in the DataFrame

# %%
data.duplicated().sum()   # calculates the number of duplicate rows in the DataFrame
# Out:
# 0

# %% [markdown]
# - Above operation efficiently calculates and returns the count of duplicate rows in the DataFrame, the output of 0 indicating that there are no duplicate rows present.

# %% [markdown]
# # 3. Exploratory Data Analysis(EDA)

# %% [markdown]
# ### 3.1 Demographic Analysis:

# %% [markdown]
# ## 👇 Categorising Age Distribution

# %%
# Demographic Analysis
age_distribution = data['Age'].value_counts()
gender_distribution = data['Gender'].value_counts()
blood_type_distribution = data['Blood Type'].value_counts()
# Plotting Age Distribution
plt.figure(figsize=(15, 6))
plt.bar(age_distribution.index, age_distribution.values, color='skyblue')
plt.xlabel('Age',weight = 'bold', fontsize = 15)
plt.ylabel('Number of Patients',weight = 'bold',fontsize = 10)
plt.title('Age Distribution of Patients',weight = 'bold',fontsize = 20)
plt.grid(True)
plt.show()

# %% [markdown]
# ## 👇 Percentage of Gender Distribution of Patients

# %%
# Plotting Gender Distribution
plt.figure(figsize=(6, 6))
plt.pie(gender_distribution, labels=gender_distribution.index, autopct='%1.1f%%', colors=['lightcoral', 'lightskyblue'])
plt.title('Gender Distribution of Patients')
plt.show()

# %% [markdown]
# - The above pie chart illustrates the gender distribution among patients:
#                                                                       Females:- 50.7%
#                                                                       Males :- 49.3%

# %% [markdown]
# ## 👇 Categorising Blood Type Distribution

# %%
# Plotting Blood Type Distribution
plt.figure(figsize=(8, 6))
blood_type_distribution.plot(kind='bar', color='lightgreen', ylim= (1200,1300))
ax = blood_type_distribution.plot(kind='bar', stacked=False, edgecolor='k')

# Add bar values on top of bars
for p in ax.patches:
    ax.annotate(np.round(p.get_height(), decimals=2),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 5),
                textcoords='offset points')
plt.xlabel('Blood Type',weight = 'bold', fontsize = 15)
plt.ylabel('Number of Patients',weight = 'bold', fontsize = 15)
plt.title('Blood Type Distribution of Patients',weight = 'bold',fontsize = 20)
plt.show()

# %% [markdown]
# ### The Above bar chart displays the Blood type distribution for 10000 patients in the Dataset:
# - AB- as the most prevalent blood type patients and A- as the least prevalent blood type patients.

# %% [markdown]
# ## 👇 Created a heatmap of admission types based on age

# %%
# Create a heatmap of admission types based on age
age_admission_trends = data.groupby(['Age', 'Admission Type'])['Name'].count().unstack()
plt.figure(figsize=(20, 20))  
sns.heatmap(age_admission_trends, cmap="Reds", annot=True, fmt='d')  # Create the heatmap
plt.xlabel('Admission Type',weight = 'bold', fontsize = 15)  
plt.ylabel('Age',weight = 'bold', fontsize = 15)
plt.title('Heatmap of Admission Types based on Age',weight = 'bold', fontsize = 20)
plt.xticks(rotation=0)  
plt.yticks(rotation=0)  
plt.show()

# %% [markdown]
# ## 👇 Group data by Gender and Admission Type and created a bar plot

# %%
gender_admission_trends = data.groupby(['Gender', 'Admission Type'])['Name'].count().unstack()

ax = gender_admission_trends.plot(kind='bar', stacked=False, edgecolor='k')  # Create the bar plot

# Add bar values on top of bars
for p in ax.patches:
    ax.annotate(np.round(p.get_height(), decimals=2),  # Annotate the bar height
                (p.get_x() + p.get_width() / 2., p.get_height()),  # Position of the annotation
                ha='center', va='center', xytext=(0, 5),  # Alignment and offset of the annotation
                textcoords='offset points')  # Annotation text coordinates

plt.xlabel('Gender',weight = 'bold', fontsize = 15)
plt.ylabel('Number of Patients',weight = 'bold', fontsize = 15)
plt.title('Trends in Admission Types based on Gender',weight = 'bold',fontsize = 18)
plt.xticks(rotation=0)
plt.legend(title='Admission Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# - The Above bar chart displays in each and every Admission type Females are higher compared with Males.

# %% [markdown]
# ## 👇 Count the occurrences of each admission type

# %%
# Admission type analysis
admission_type_counts = data['Admission Type'].value_counts()
print("\nAdmission Type Analysis:")
print(admission_type_counts)
# Out:
# Admission Type Analysis:
# Admission Type
# Urgent       3391
# Emergency    3367
# Elective     3242
# Name: count, dtype: int64

# %% [markdown]
# ## 👇 Categorized Medical Condition Analysis

# %%
# Medical Condition Analysis
medical_condition_counts = data['Medical Condition'].value_counts()

# Plotting Medical Condition Analysis
plt.figure(figsize=(10, 6))

ax = medical_condition_counts.plot(kind='bar', stacked=False, edgecolor='k')  # Create the bar plot

# Add bar values on top of bars
for p in ax.patches:
    ax.annotate(np.round(p.get_height(), decimals=2),  # Annotate the bar height
                (p.get_x() + p.get_width() / 2., p.get_height()),  # Position of the annotation
                ha='center', va='center', xytext=(0, 5),  # Alignment and offset of the annotation
                textcoords='offset points')  # Annotation text coordinates
    
medical_condition_counts.plot(kind='bar',ylim=(1500,1800),edgecolor='k')
plt.title('Medical Condition Distribution',weight = 'bold', fontsize = 15)
plt.xlabel('Medical Condition',weight = 'bold', fontsize = 15)
plt.ylabel('Frequency',weight = 'bold', fontsize = 15)
plt.xticks(rotation=0, ha='center')
plt.tight_layout()
plt.show()

# %% [markdown]
# - The Above bar plot visualizes the distribution of medical conditions, with asthma exhibiting the highest frequency among patients.
# - Conversely, diabetes emerges as the medical condition with the lowest frequency in the dataset.

# %% [markdown]
# ## 👇 Categorized Insurance Provider

# %%
# Insurance Provider Analysis
insurance_provider_counts = data['Insurance Provider'].value_counts()

# Plotting Insurance Provider Analysis
plt.figure(figsize=(10, 6))
ax = insurance_provider_counts.plot(kind='bar', stacked=False, edgecolor='k')  # Create the bar plot

# Add bar values on top of bars
for p in ax.patches:
    ax.annotate(np.round(p.get_height(), decimals=2),  # Annotate the bar height
                (p.get_x() + p.get_width() / 2., p.get_height()),  # Position of the annotation
                ha='center', va='center', xytext=(0, 5),  # Alignment and offset of the annotation
                textcoords='offset points')  # Annotation text coordinates
    
insurance_provider_counts.plot(kind='bar',ylim=(1500,2100),edgecolor='k')
plt.title('Insurance Provider Distribution',weight = 'bold', fontsize = 20)
plt.xlabel('Insurance Provider',weight = 'bold', fontsize = 15)
plt.ylabel('Frequency',weight = 'bold', fontsize = 15)
plt.xticks(rotation=0, ha='center')
plt.tight_layout()
plt.show()

# %% [markdown]
# - From the above bar chart Cigna Provides more Insurance and Medicare Provides Least Insurance.

# %% [markdown]
# ## 👇 Categorized Top 5 Most Frequently Used Medications

# %%
# Analyze medication usage
medication_counts = data['Medication'].value_counts()  # Count occurrences of each medication
top_5_medications = medication_counts.head(10)  # Get top 10 most frequent medications

# Create bar chart 
plt.figure(figsize=(10, 6))  # Adjust figure size as needed

ax = top_5_medications.plot(kind='bar', stacked=False, edgecolor='k')  # Create the bar plot

# Add bar values on top of bars
for p in ax.patches:
    ax.annotate(np.round(p.get_height(), decimals=2),  # Annotate the bar height
                (p.get_x() + p.get_width() / 2., p.get_height()),  # Position of the annotation
                ha='center', va='center', xytext=(0, 5),  # Alignment and offset of the annotation
                textcoords='offset points')  # Annotation text coordinates

if len(top_5_medications) <= 20:
  top_5_medications.plot(kind='bar',ylim = (1700,2200), color='skyblue', edgecolor='black')
  plt.title("Top 5 Most Frequently Used Medications",weight = 'bold', fontsize = 20)
  plt.xlabel("Medication",ha = 'right',weight = 'bold', fontsize = 15)
  plt.ylabel("Count",weight = 'bold', fontsize = 15)
  plt.xticks(rotation=0, ha='center')  # Rotate medication names for readability (optional)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 👇 Percentage of medication and Medical conditions

# %%
# Analyze medication usage
medication_counts = data['Medication'].value_counts()  # Count occurrences of each medication
top_10_medications = medication_counts.head(10)  # Get top 10 most frequent medications

# Create pie charts
plt.figure(figsize=(10, 6))  # Adjust figure size as needed

# Medication usage pie chart
plt.subplot(121)  # Create first subplot for medication usage
top_10_medications.plot(kind='pie', autopct='%1.1f%%', startangle=105)  # Adjust startangle for better visualization
plt.title("Top 10 Medications (Pie Chart)")

# Medical condition usage pie chart
plt.subplot(122)  # Create second subplot for medical condition usage
medical_condition_counts.plot(kind='pie', autopct='%1.1f%%', startangle=60)  # Adjust startangle for better visualization
plt.title("Medical Conditions (Pie Chart)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 👇 Plotting the average billing amount by medical condition

# %%
# Import necessary libraries
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(12, 6))

# Group data by Medical Condition and calculate the average billing amount
avg_cost_by_condition = data.groupby('Medical Condition')['Billing Amount'].mean()

# Plot the data with green circles and dashed lines
plt.plot(avg_cost_by_condition, "g*", markersize=10)  

# Annotate each point with its corresponding value
for condition, cost in avg_cost_by_condition.items():
    plt.annotate(f"{cost:.2f} ₹", (condition, cost), textcoords="offset points", xytext=(0,6), ha='center')

plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.xlabel('Medical condition',weight = 'bold', fontsize = 15)
plt.ylabel('Average Billing Amount',weight = 'bold', fontsize = 15)  # Set the label for the y-axis
plt.title('Average Billing Amount by Medical Condition',weight = 'bold', fontsize = 20)  # Set the title of the plot
plt.grid(True)  # Add gridlines to the plot
plt.show()  # Display the plot

# %% [markdown]
# - This plot visualizes the average billing amount for different medical conditions like Arthritis, Asthma, Cancer, Diabetes, Hypertension and Obesity.
# - Diabetes has the highest average billing amount, while Arthritis has the lowest.
# - The plot highlights variations in billing amounts across various medical conditions, aiding in understanding healthcare expenditure patterns.

# %% [markdown]
# ## 👇 Plotting Average Billing Amount Vs Admission Type

# %%
plt.figure(figsize=(12, 6))
avg_cost_by_admission_type = data.groupby('Admission Type')['Billing Amount'].mean()
plt.plot(avg_cost_by_admission_type, "bo",markersize=4)  # Plot the data with blue circles and dashed lines

# Annotate each point with its corresponding value
for x, y in zip(avg_cost_by_admission_type.index, avg_cost_by_admission_type):
    plt.text(x, y, f'{y:.2f} ₹', ha='center', va='bottom')

plt.title("Average Billing Amount by Admission Type",weight = 'bold', fontsize = 20)  # Set the title of the plot
plt.ylabel("Average Billing Amount",weight = 'bold', fontsize = 15)  # Set the label for the y-axis
plt.xlabel('Admission Type',weight = 'bold', fontsize = 15)  # Set the label for the x-axis
plt.grid(True)  # Add gridlines to the plot
plt.show()  # Display the plot

# %% [markdown]
# - This plot depicts the average billing amount across different admission types.
# - Urgent admission type exhibits the highest average billing amount, while emergency admission type displays the lowest.
# - Understanding variations in billing amounts by admission type aids in healthcare resource allocation and financial planning.

# %% [markdown]
# ## 👇 Created a histogram of the Billing Amount Vs No. fo patients

# %%
plt.figure(figsize=(12, 6))
hist = data['Billing Amount'].plot.hist(bins=20, edgecolor='k', ylim=(400, 600))  # Adjust bin count and ylim as needed
plt.title("Distribution of Billing Amounts",weight = 'bold', fontsize = 20)
plt.xlabel("Billing Amount",weight = 'bold', fontsize = 15)
plt.ylabel("Number of Patients",weight = 'bold', fontsize = 15)
plt.grid(True)

# Annotate each bar with its corresponding count
for rect in hist.patches:
    plt.text(rect.get_x() + rect.get_width() / 2, rect.get_height(), int(rect.get_height()),
             ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Conclusion
# ### The Heathcare sales dataset provides values insights of patients trends on medicines selling. Through careful analysis of the given data. Several keys are found
#
# - Females are most likely to be sick than males.
# - AB- blood group people are more likely to get diseases than other blood groups people.
# - A- blood group people are less likely to get diseases than other blood groups people.
# - In medical condition diabetes is the most highest average billing is paid.
# - Penicillin is the top medication used among the all medicines.
